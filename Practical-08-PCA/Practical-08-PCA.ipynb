# %% [markdown]
# <a href="https://colab.research.google.com/github/tishamondal-stargazer/Machine-Learning/blob/main/Practical-08-PCA/Practical-08-PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CS23059 Tisha Mondal

# %% [markdown]
# ML LAB-8
#
# Aim:To apply principal component analysis for dimensionality reduction and visualize the transformed features space

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
iris=load_iris()
x=iris.data
y=iris.target

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
print('explained variance ratio')
pca.explained_variance_ratio_
# Out:
# explained variance ratio
# array([0.72962445, 0.22850762])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
pca=PCA()
pca.fit(x_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()
